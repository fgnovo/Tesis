# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import base as features
import scipy.io.wavfile as wav
import os
import subprocess
import csv
import numpy as np
import pickle
import tensorflow as tf
import time
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error,f1_score
from scipy.stats import pearsonr
from collections import Counter
from imblearn.over_sampling import SMOTE

#***********************************************************
#              PREPROCESSING CONFIGURATION
#***********************************************************
directory_in_audio = '/home2/plopez/BBDD/AVEC2014/Audio/audio/'
directory_label = '/home2/plopez/BBDD/AVEC2014/Testing/Depression/'
directory_out = '/home/projects/fgnovo/workspace/Tesis/BBDD/AVEC2014/'
winlen = 0.02
winstep = 0.01
nfilt = 40
nfft = 512
lowfreq = 0
preemph = 0.97
time_segment = 3
log_mel_filterbank_features = 40
rate_mpeg = "16k"
# Out:
# /usr/local/lib/python2.7/dist-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# THE NEXT TWO CELLS ONLY HAVE TO BE EXECUTED THE FIRST TIME, OR WHEN YOU LIKE CHANGE THE PREPROCESSING

# %%
def process_audio_file_logmel(nfile_audio, directory_out,directory_in_audio,label, time_segment,rate_mpeg,total_data_log_coef,data_matrix):
    name_out = "salida.wav"
    command = "ffmpeg -i "+directory_in_audio+nfile+" -ab "+rate_mpeg +" -ac 1 -ar "+rate_mpeg+" -vn "+directory_out+name_out
    subprocess.call(command,shell=True)
    (rate,data) = wav.read(directory_out+name_out)
    os.remove(directory_out+name_out)
    len_utterance = time_segment*rate
    num_utterance = len(data)//len_utterance
    print ("Num utterances: {0}".format(num_utterance))
    for i in range(num_utterance):
        data_utterance = data[i*len_utterance:(i+1)*len_utterance]
        data_log_coef  = features.logfbank(data_utterance,samplerate = rate,winlen = winlen,winstep = winstep,nfilt = nfilt,nfft = nfft,lowfreq = lowfreq,highfreq = rate/2,preemph = preemph)
        element = [data_log_coef,label]
        if not total_data_log_coef :
            total_data_log_coef = [element]
        else:
            total_data_log_coef.append(element)
        if data_matrix.shape[0] == 0:
            data_matrix = data_log_coef
        else:
            data_matrix = np.vstack((data_matrix,data_log_coef))
    return(total_data_log_coef,data_matrix)     

def process_labels(directory_label):
    files = os.listdir(directory_label)
    list_labels = {}
    for nfile in files:
        lname = nfile.split('_')
        name = lname[0]+lname[1]
        f = open(directory_label+nfile)
        label = int(f.readline())
        list_labels.update({name:label})
    return(list_labels)

# %%
files = os.listdir(directory_in_audio)
labels = process_labels(directory_label)
total_data_log_coef = list()
data_matrix = np.array([])
i = 1
for nfile in files:
    lname = nfile.split('_')
    name = lname[0]+lname[1]
    label = labels[name]
    print ('Processing file {0} with label {1}, number {2}'.format(nfile,label,i))
    i+=1
    (total_data_log_coef,data_matrix) = process_audio_file_logmel(nfile, directory_out,directory_in_audio,label, time_segment,rate_mpeg,total_data_log_coef,data_matrix)
print ('Procesado de archivos finalizados')
print ('Standarization......')
mean = np.mean(data_matrix,axis = 0)
standard_deviation = np.std(data_matrix,axis=0)
data_matrix = []
for utterance in total_data_log_coef:
    utterance[0] = (utterance[0]-mean)/standard_deviation
print('Saving data')
output = open(directory_out+'datos_procesados','wb') 
pickle.dump(total_data_log_coef,output)
output.close()
total_data_log_coef=[]
print('Finished')
# Out:
# Processing file 218_3_Northwind_audio.mp4 with label 22, number 1
# Num utterances: 13
# Processing file 246_2_Freeform_audio.mp4 with label 29, number 2
# Num utterances: 36
# Processing file 241_2_Freeform_audio.mp4 with label 44, number 3
# Num utterances: 2
# Processing file 217_2_Northwind_audio.mp4 with label 30, number 4
# Num utterances: 22
# Processing file 368_1_Northwind_audio.mp4 with label 11, number 5
# Num utterances: 13
# Processing file 358_1_Freeform_audio.mp4 with label 22, number 6
# Num utterances: 37
# Processing file 219_3_Northwind_audio.mp4 with label 19, number 7
# Num utterances: 13
# Processing file 218_2_Northwind_audio.mp4 with label 24, number 8
# Num utterances: 13
# Processing file 236_1_Northwind_audio.mp4 with label 23, number 9
# Num utterances: 14
# Processing file 242_3_Northwind_audio.mp4 with label 9, number 10
# Num utterances: 13
# Processing file 310_4_Northwind_audio.mp4 with label 19, number 11
# Num utterances: 13
# Processing file 364_1_Northwind_audio.mp4 with label 0, number 12
# Num utterances: 13
# Processing file 227_2_Freeform_audio.mp4 with label 13, number 13
# Num utterances: 16
# Processing file 306_3_Freeform_audio.mp4 with label 19, number 14
# Num utterances: 5
# Processing file 323_1_Freeform_audio.mp4 with label 12, number 15
# Num utterances: 21
# Processing file 234_3_Northwind_audio.mp4 with label 23, number 16
# Num utterances: 12
# Processing file 230_1_Freeform_audio.mp4 with label 20, number 17
# Num utterances: 2
# Processing file 241_3_Freeform_audio.mp4 with label 40, number 18
# Num utterances: 2
# Processing file 236_2_Northwind_audio.mp4 with label 25, number 19
# Num utterances: 14
# Processing file 203_1_Freeform_audio.mp4 with label 3, number 20
# Num utterances: 10
# Processing file 247_3_Northwind_audio.mp4 with label 9, number 21
# Num utterances: 12
# Processing file 221_1_Freeform_audio.mp4 with label 0, number 22
# Num utterances: 9
# Processing file 224_1_Northwind_audio.mp4 with label 29, number 23
# Num utterances: 21
# Processing file 237_2_Freeform_audio.mp4 with label 34, number 24
# Num utterances: 4
# Processing file 209_1_Northwind_audio.mp4 with label 6, number 25
# Num utterances: 13
# Processing file 331_1_Northwind_audio.mp4 with label 5, number 26
# Num utterances: 13
# Processing file 225_1_Freeform_audio.mp4 with label 17, number 27
# Num utterances: 10
# Processing file 215_2_Freeform_audio.mp4 with label 9, number 28
# Num utterances: 9
# Processing file 220_2_Freeform_audio.mp4 with label 18, number 29
# Num utterances: 8
# Processing file 240_2_Northwind_audio.mp4 with label 16, number 30
# Num utterances: 13
# Processing file 223_1_Freeform_audio.mp4 with label 0, number 31
# Num utterances: 41
# Processing file 228_1_Northwind_audio.mp4 with label 1, number 32
# Num utterances: 12
# Processing file 243_1_Northwind_audio.mp4 with label 41, number 33
# Num utterances: 13
# Processing file 368_1_Freeform_audio.mp4 with label 11, number 34
# Num utterances: 40
# Processing file 341_2_Freeform_audio.mp4 with label 12, number 35
# Num utterances: 11
# Processing file 239_2_Northwind_audio.mp4 with label 13, number 36
# Num utterances: 11
# Processing file 231_1_Northwind_audio.mp4 with label 32, number 37
# Num utterances: 19
# Processing file 211_2_Northwind_audio.mp4 with label 3, number 38
# Num utterances: 15
# Processing file 324_1_Northwind_audio.mp4 with label 0, number 39
# Num utterances: 19
# Processing file 357_2_Northwind_audio.mp4 with label 15, number 40
# Num utterances: 15
# Processing file 328_1_Northwind_audio.mp4 with label 7, number 41
# Num utterances: 17
# Processing file 203_2_Northwind_audio.mp4 with label 8, number 42
# Num utterances: 10
# Processing file 313_3_Freeform_audio.mp4 with label 0, number 43
# Num utterances: 4
# Processing file 319_1_Freeform_audio.mp4 with label 4, number 44
# Num utterances: 18
# Processing file 318_2_Northwind_audio.mp4 with label 12, number 45
# Num utterances: 13
# Processing file 219_1_Freeform_audio.mp4 with label 33, number 46
# Num utterances: 36
# Processing file 225_2_Northwind_audio.mp4 with label 15, number 47
# Num utterances: 15
# Processing file 224_1_Freeform_audio.mp4 with label 29, number 48
# Num utterances: 7
# Processing file 315_2_Northwind_audio.mp4 with label 34, number 49
# Num utterances: 19
# Processing file 243_1_Freeform_audio.mp4 with label 41, number 50
# Num utterances: 21
# Processing file 242_1_Freeform_audio.mp4 with label 16, number 51
# Num utterances: 50
# Processing file 346_1_Freeform_audio.mp4 with label 14, number 52
# Num utterances: 48
# Processing file 318_1_Freeform_audio.mp4 with label 7, number 53
# Num utterances: 12
# Processing file 313_3_Northwind_audio.mp4 with label 0, number 54
# Num utterances: 19
# Processing file 315_3_Freeform_audio.mp4 with label 17, number 55
# Num utterances: 28
# Processing file 206_1_Northwind_audio.mp4 with label 8, number 56
# Num utterances: 11
# Processing file 320_3_Freeform_audio.mp4 with label 5, number 57
# Num utterances: 18
# Processing file 335_2_Freeform_audio.mp4 with label 0, number 58
# Num utterances: 18
# Processing file 317_3_Freeform_audio.mp4 with label 17, number 59
# Num utterances: 37
# Processing file 325_2_Freeform_audio.mp4 with label 25, number 60
# Num utterances: 15
# Processing file 213_2_Northwind_audio.mp4 with label 29, number 61
# Num utterances: 12
# Processing file 310_2_Freeform_audio.mp4 with label 19, number 62
# Num utterances: 5
# Processing file 228_2_Freeform_audio.mp4 with label 0, number 63
# Num utterances: 7
# Processing file 214_1_Northwind_audio.mp4 with label 11, number 64
# Num utterances: 15
# Processing file 320_3_Northwind_audio.mp4 with label 5, number 65
# Num utterances: 12
# Processing file 239_3_Freeform_audio.mp4 with label 9, number 66
# Num utterances: 8
# Processing file 246_1_Northwind_audio.mp4 with label 43, number 67
# Num utterances: 44
# Processing file 341_2_Northwind_audio.mp4 with label 12, number 68
# Num utterances: 13
# Processing file 232_2_Northwind_audio.mp4 with label 12, number 69
# Num utterances: 11
# Processing file 241_1_Freeform_audio.mp4 with label 45, number 70
# Num utterances: 3
# Processing file 214_3_Freeform_audio.mp4 with label 18, number 71
# Num utterances: 14
# Processing file 234_1_Northwind_audio.mp4 with label 31, number 72
# Num utterances: 13
# Processing file 317_4_Freeform_audio.mp4 with label 0, number 73
# Num utterances: 38
# Processing file 319_2_Freeform_audio.mp4 with label 2, number 74
# Num utterances: 11
# Processing file 240_2_Freeform_audio.mp4 with label 16, number 75
# Num utterances: 30
# Processing file 237_3_Freeform_audio.mp4 with label 37, number 76
# Num utterances: 4
# Processing file 306_2_Northwind_audio.mp4 with label 22, number 77
# Num utterances: 15
# Processing file 219_2_Northwind_audio.mp4 with label 6, number 78
# Num utterances: 13
# Processing file 208_2_Northwind_audio.mp4 with label 4, number 79
# Num utterances: 15
# Processing file 331_3_Northwind_audio.mp4 with label 0, number 80
# Num utterances: 12
# Processing file 219_2_Freeform_audio.mp4 with label 6, number 81
# Num utterances: 31
# Processing file 211_1_Freeform_audio.mp4 with label 3, number 82
# Num utterances: 13
# Processing file 312_2_Northwind_audio.mp4 with label 0, number 83
# Num utterances: 11
# Processing file 317_1_Northwind_audio.mp4 with label 24, number 84
# Num utterances: 17
# Processing file 225_1_Northwind_audio.mp4 with label 17, number 85
# Num utterances: 18
# Processing file 215_2_Northwind_audio.mp4 with label 9, number 86
# Num utterances: 20
# Processing file 347_2_Northwind_audio.mp4 with label 3, number 87
# Num utterances: 13
# Processing file 220_3_Northwind_audio.mp4 with label 15, number 88
# Num utterances: 13
# Processing file 247_1_Northwind_audio.mp4 with label 14, number 89
# Num utterances: 12
# Processing file 334_1_Freeform_audio.mp4 with label 1, number 90
# Num utterances: 48
# Processing file 208_2_Freeform_audio.mp4 with label 4, number 91
# Num utterances: 23
# Processing file 214_2_Freeform_audio.mp4 with label 6, number 92
# Num utterances: 30
# Processing file 216_2_Northwind_audio.mp4 with label 21, number 93
# Num utterances: 13
# Processing file 220_1_Northwind_audio.mp4 with label 10, number 94
# Num utterances: 13
# Processing file 244_2_Freeform_audio.mp4 with label 27, number 95
# Num utterances: 40
# Processing file 229_1_Northwind_audio.mp4 with label 21, number 96
# Num utterances: 15
# Processing file 211_1_Northwind_audio.mp4 with label 3, number 97
# Num utterances: 16
# Processing file 306_2_Freeform_audio.mp4 with label 22, number 98
# Num utterances: 4
# Processing file 323_3_Northwind_audio.mp4 with label 27, number 99
# Num utterances: 11
# Processing file 226_1_Northwind_audio.mp4 with label 35, number 100
# Num utterances: 13
# Processing file 238_2_Freeform_audio.mp4 with label 37, number 101
# Num utterances: 2
# Processing file 206_1_Freeform_audio.mp4 with label 8, number 102
# Num utterances: 21
# Processing file 229_2_Freeform_audio.mp4 with label 17, number 103
# Num utterances: 18
# Processing file 308_3_Freeform_audio.mp4 with label 21, number 104
# Num utterances: 2
# Processing file 357_2_Freeform_audio.mp4 with label 15, number 105
# Num utterances: 13
# Processing file 358_1_Northwind_audio.mp4 with label 22, number 106
# Num utterances: 19
# Processing file 250_1_Freeform_audio.mp4 with label 27, number 107
# Num utterances: 9
# Processing file 232_2_Freeform_audio.mp4 with label 12, number 108
# Num utterances: 31
# Processing file 341_1_Northwind_audio.mp4 with label 7, number 109
# Num utterances: 13
# Processing file 246_2_Northwind_audio.mp4 with label 29, number 110
# Num utterances: 14
# Processing file 247_1_Freeform_audio.mp4 with label 14, number 111
# Num utterances: 50
# Processing file 329_1_Freeform_audio.mp4 with label 24, number 112
# Num utterances: 29
# Processing file 242_3_Freeform_audio.mp4 with label 9, number 113
# Num utterances: 37
# Processing file 226_1_Freeform_audio.mp4 with label 35, number 114
# Num utterances: 30
# Processing file 219_1_Northwind_audio.mp4 with label 33, number 115
# Num utterances: 14
# Processing file 223_1_Northwind_audio.mp4 with label 0, number 116
# Num utterances: 13
# Processing file 332_4_Northwind_audio.mp4 with label 0, number 117
# Num utterances: 11
# Processing file 315_2_Freeform_audio.mp4 with label 34, number 118
# Num utterances: 39
# Processing file 364_1_Freeform_audio.mp4 with label 0, number 119
# Num utterances: 26
# Processing file 345_3_Freeform_audio.mp4 with label 0, number 120
# Num utterances: 13
# Processing file 236_3_Northwind_audio.mp4 with label 19, number 121
# Num utterances: 13
# Processing file 246_1_Freeform_audio.mp4 with label 43, number 122
# Num utterances: 49
# Processing file 237_1_Freeform_audio.mp4 with label 41, number 123
# Num utterances: 5
# Processing file 226_2_Northwind_audio.mp4 with label 30, number 124
# Num utterances: 13
# Processing file 239_2_Freeform_audio.mp4 with label 13, number 125
# Num utterances: 6
# Processing file 320_1_Northwind_audio.mp4 with label 3, number 126
# Num utterances: 13
# Processing file 328_1_Freeform_audio.mp4 with label 7, number 127
# Num utterances: 19
# Processing file 228_2_Northwind_audio.mp4 with label 0, number 128
# Num utterances: 11
# Processing file 211_2_Freeform_audio.mp4 with label 3, number 129
# Num utterances: 32
# Processing file 239_3_Northwind_audio.mp4 with label 9, number 130
# Num utterances: 10
# Processing file 237_2_Northwind_audio.mp4 with label 34, number 131
# Num utterances: 15
# Processing file 223_2_Northwind_audio.mp4 with label 0, number 132
# Num utterances: 13
# Processing file 241_1_Northwind_audio.mp4 with label 45, number 133
# Num utterances: 13
# Processing file 232_1_Northwind_audio.mp4 with label 10, number 134
# Num utterances: 13
# Processing file 341_1_Freeform_audio.mp4 with label 7, number 135
# Num utterances: 37
# Processing file 208_1_Freeform_audio.mp4 with label 5, number 136
# Num utterances: 23
# Processing file 240_1_Northwind_audio.mp4 with label 14, number 137
# Num utterances: 14
# Processing file 239_1_Northwind_audio.mp4 with label 22, number 138
# Num utterances: 11
# Processing file 359_1_Freeform_audio.mp4 with label 33, number 139
# Num utterances: 27
# Processing file 218_1_Freeform_audio.mp4 with label 31, number 140
# Num utterances: 6
# Processing file 318_3_Northwind_audio.mp4 with label 7, number 141
# Num utterances: 12
# Processing file 241_2_Northwind_audio.mp4 with label 44, number 142
# Num utterances: 13
# Processing file 238_3_Northwind_audio.mp4 with label 39, number 143
# Num utterances: 29
# Processing file 207_1_Freeform_audio.mp4 with label 12, number 144
# Num utterances: 25
# Processing file 234_1_Freeform_audio.mp4 with label 31, number 145
# Num utterances: 2
# Processing file 215_3_Freeform_audio.mp4 with label 5, number 146
# Num utterances: 7
# Processing file 236_2_Freeform_audio.mp4 with label 25, number 147
# Num utterances: 16
# Processing file 315_3_Northwind_audio.mp4 with label 17, number 148
# Num utterances: 13
# Processing file 217_2_Freeform_audio.mp4 with label 30, number 149
# Num utterances: 21
# Processing file 227_2_Northwind_audio.mp4 with label 13, number 150
# Num utterances: 13
# Processing file 215_1_Freeform_audio.mp4 with label 21, number 151
# Num utterances: 6
# Processing file 310_2_Northwind_audio.mp4 with label 19, number 152
# Num utterances: 13
# Processing file 342_3_Northwind_audio.mp4 with label 9, number 153
# Num utterances: 25
# Processing file 319_2_Northwind_audio.mp4 with label 2, number 154
# Num utterances: 12
# Processing file 217_3_Freeform_audio.mp4 with label 32, number 155
# Num utterances: 9
# Processing file 344_2_Northwind_audio.mp4 with label 3, number 156
# Num utterances: 13
# Processing file 207_2_Freeform_audio.mp4 with label 10, number 157
# Num utterances: 12
# Processing file 331_1_Freeform_audio.mp4 with label 5, number 158
# Num utterances: 31
# Processing file 249_1_Freeform_audio.mp4 with label 4, number 159
# Num utterances: 13
# Processing file 329_1_Northwind_audio.mp4 with label 24, number 160
# Num utterances: 14
# Processing file 207_2_Northwind_audio.mp4 with label 10, number 161
# Num utterances: 12
# Processing file 242_2_Freeform_audio.mp4 with label 11, number 162
# Num utterances: 23
# Processing file 220_3_Freeform_audio.mp4 with label 15, number 163
# Num utterances: 19
# Processing file 225_2_Freeform_audio.mp4 with label 15, number 164
# Num utterances: 5
# Processing file 244_1_Northwind_audio.mp4 with label 29, number 165
# Num utterances: 20
# Processing file 333_1_Freeform_audio.mp4 with label 3, number 166
# Num utterances: 33
# Processing file 318_1_Northwind_audio.mp4 with label 7, number 167
# Num utterances: 16
# Processing file 342_3_Freeform_audio.mp4 with label 9, number 168
# Num utterances: 34
# Processing file 214_1_Freeform_audio.mp4 with label 11, number 169
# Num utterances: 22
# Processing file 205_1_Freeform_audio.mp4 with label 6, number 170
# Num utterances: 11
# Processing file 214_2_Northwind_audio.mp4 with label 6, number 171
# Num utterances: 15
# Processing file 318_2_Freeform_audio.mp4 with label 12, number 172
# Num utterances: 8
# Processing file 332_2_Freeform_audio.mp4 with label 2, number 173
# Num utterances: 34
# Processing file 343_1_Northwind_audio.mp4 with label 3, number 174
# Num utterances: 13
# Processing file 222_1_Freeform_audio.mp4 with label 16, number 175
# Num utterances: 51
# Processing file 218_3_Freeform_audio.mp4 with label 22, number 176
# Num utterances: 13
# Processing file 236_1_Freeform_audio.mp4 with label 23, number 177
# Num utterances: 9
# Processing file 249_1_Northwind_audio.mp4 with label 4, number 178
# Num utterances: 14
# Processing file 357_1_Freeform_audio.mp4 with label 15, number 179
# Num utterances: 26
# Processing file 238_2_Northwind_audio.mp4 with label 37, number 180
# Num utterances: 28
# Processing file 216_1_Northwind_audio.mp4 with label 18, number 181
# Num utterances: 14
# Processing file 205_2_Northwind_audio.mp4 with label 3, number 182
# Num utterances: 11
# Processing file 234_2_Northwind_audio.mp4 with label 28, number 183
# Num utterances: 14
# Processing file 236_3_Freeform_audio.mp4 with label 19, number 184
# Num utterances: 17
# Processing file 321_2_Freeform_audio.mp4 with label 11, number 185
# Num utterances: 9
# Processing file 332_2_Northwind_audio.mp4 with label 2, number 186
# Num utterances: 11
# Processing file 233_1_Freeform_audio.mp4 with label 4, number 187
# Num utterances: 38
# Processing file 245_1_Northwind_audio.mp4 with label 25, number 188
# Num utterances: 16
# Processing file 206_2_Freeform_audio.mp4 with label 3, number 189
# Num utterances: 18
# Processing file 234_3_Freeform_audio.mp4 with label 23, number 190
# Num utterances: 3
# Processing file 358_2_Freeform_audio.mp4 with label 23, number 191
# Num utterances: 15
# Processing file 242_2_Northwind_audio.mp4 with label 11, number 192
# Num utterances: 13
# Processing file 213_3_Freeform_audio.mp4 with label 23, number 193
# Num utterances: 10
# Processing file 210_2_Freeform_audio.mp4 with label 1, number 194
# Num utterances: 29
# Processing file 240_1_Freeform_audio.mp4 with label 14, number 195
# Num utterances: 13
# Processing file 365_1_Northwind_audio.mp4 with label 0, number 196
# Num utterances: 18
# Processing file 365_1_Freeform_audio.mp4 with label 0, number 197
# Num utterances: 82
# Processing file 209_2_Freeform_audio.mp4 with label 9, number 198
# Num utterances: 26
# Processing file 232_1_Freeform_audio.mp4 with label 10, number 199
# Num utterances: 39
# Processing file 237_3_Northwind_audio.mp4 with label 37, number 200
# Num utterances: 13
# Processing file 240_3_Northwind_audio.mp4 with label 11, number 201
# Num utterances: 13
# Processing file 215_3_Northwind_audio.mp4 with label 5, number 202
# Num utterances: 15
# Processing file 250_1_Northwind_audio.mp4 with label 27, number 203
# Num utterances: 13
# Processing file 206_2_Northwind_audio.mp4 with label 3, number 204
# Num utterances: 11
# Processing file 351_1_Northwind_audio.mp4 with label 6, number 205
# Num utterances: 12
# Processing file 217_3_Northwind_audio.mp4 with label 32, number 206
# Num utterances: 22
# Processing file 244_1_Freeform_audio.mp4 with label 29, number 207
# Num utterances: 14
# Processing file 214_3_Northwind_audio.mp4 with label 18, number 208
# Num utterances: 14
# Processing file 229_2_Northwind_audio.mp4 with label 17, number 209
# Num utterances: 14
# Processing file 240_3_Freeform_audio.mp4 with label 11, number 210
# Num utterances: 35
# Processing file 205_2_Freeform_audio.mp4 with label 3, number 211
# Num utterances: 8
# Processing file 332_1_Northwind_audio.mp4 with label 1, number 212
# Num utterances: 11
# Processing file 338_1_Freeform_audio.mp4 with label 12, number 213
# Num utterances: 17
# Processing file 229_1_Freeform_audio.mp4 with label 21, number 214
# Num utterances: 23
# Processing file 218_2_Freeform_audio.mp4 with label 24, number 215
# Num utterances: 9
# Processing file 203_2_Freeform_audio.mp4 with label 8, number 216
# Num utterances: 11
# Processing file 306_3_Northwind_audio.mp4 with label 19, number 217
# Num utterances: 14
# Processing file 323_3_Freeform_audio.mp4 with label 27, number 218
# Num utterances: 21
# Processing file 244_3_Northwind_audio.mp4 with label 25, number 219
# Num utterances: 17
# Processing file 219_3_Freeform_audio.mp4 with label 19, number 220
# Num utterances: 20
# Processing file 242_1_Northwind_audio.mp4 with label 16, number 221
# Num utterances: 14
# Processing file 347_2_Freeform_audio.mp4 with label 3, number 222
# Num utterances: 21
# Processing file 308_3_Northwind_audio.mp4 with label 21, number 223
# Num utterances: 18
# Processing file 226_2_Freeform_audio.mp4 with label 30, number 224
# Num utterances: 27
# Processing file 322_1_Freeform_audio.mp4 with label 0, number 225
# Num utterances: 34
# Processing file 237_1_Northwind_audio.mp4 with label 41, number 226
# Num utterances: 15
# Processing file 209_1_Freeform_audio.mp4 with label 6, number 227
# Num utterances: 29
# Processing file 215_1_Northwind_audio.mp4 with label 21, number 228
# Num utterances: 20
# Processing file 320_2_Northwind_audio.mp4 with label 8, number 229
# Num utterances: 13
# Processing file 227_1_Freeform_audio.mp4 with label 26, number 230
# Num utterances: 15
# Processing file 331_3_Freeform_audio.mp4 with label 0, number 231
# Num utterances: 17
# Processing file 357_1_Northwind_audio.mp4 with label 15, number 232
# Num utterances: 15
# Processing file 216_2_Freeform_audio.mp4 with label 21, number 233
# Num utterances: 11
# Processing file 209_2_Northwind_audio.mp4 with label 9, number 234
# Num utterances: 12
# Processing file 220_1_Freeform_audio.mp4 with label 10, number 235
# Num utterances: 21
# Processing file 213_1_Northwind_audio.mp4 with label 33, number 236
# Num utterances: 13
# Processing file 334_1_Northwind_audio.mp4 with label 1, number 237
# Num utterances: 12
# Processing file 332_1_Freeform_audio.mp4 with label 1, number 238
# Num utterances: 39
# Processing file 346_1_Northwind_audio.mp4 with label 14, number 239
# Num utterances: 13
# Processing file 324_1_Freeform_audio.mp4 with label 0, number 240
# Num utterances: 42
# Processing file 244_2_Northwind_audio.mp4 with label 27, number 241
# Num utterances: 19
# Processing file 213_1_Freeform_audio.mp4 with label 33, number 242
# Num utterances: 18
# Processing file 245_3_Freeform_audio.mp4 with label 21, number 243
# Num utterances: 13
# Processing file 213_3_Northwind_audio.mp4 with label 23, number 244
# Num utterances: 12
# Processing file 343_1_Freeform_audio.mp4 with label 3, number 245
# Num utterances: 36
# Processing file 212_1_Northwind_audio.mp4 with label 5, number 246
# Num utterances: 11
# Processing file 358_2_Northwind_audio.mp4 with label 23, number 247
# Num utterances: 18
# Processing file 365_2_Northwind_audio.mp4 with label 0, number 248
# Num utterances: 16
# Processing file 320_1_Freeform_audio.mp4 with label 3, number 249
# Num utterances: 11
# Processing file 319_1_Northwind_audio.mp4 with label 4, number 250
# Num utterances: 13
# Processing file 345_3_Northwind_audio.mp4 with label 0, number 251
# Num utterances: 12
# Processing file 317_1_Freeform_audio.mp4 with label 24, number 252
# Num utterances: 38
# Processing file 333_1_Northwind_audio.mp4 with label 3, number 253
# Num utterances: 13
# Processing file 244_3_Freeform_audio.mp4 with label 25, number 254
# Num utterances: 19
# Processing file 326_1_Freeform_audio.mp4 with label 6, number 255
# Num utterances: 11
# Processing file 312_2_Freeform_audio.mp4 with label 0, number 256
# Num utterances: 31
# Processing file 326_1_Northwind_audio.mp4 with label 6, number 257
# Num utterances: 13
# Processing file 351_1_Freeform_audio.mp4 with label 6, number 258
# Num utterances: 69
# Processing file 238_3_Freeform_audio.mp4 with label 39, number 259
# Num utterances: 3
# Processing file 321_2_Northwind_audio.mp4 with label 11, number 260
# Num utterances: 12
# Processing file 344_2_Freeform_audio.mp4 with label 3, number 261
# Num utterances: 8
# Processing file 231_1_Freeform_audio.mp4 with label 32, number 262
# Num utterances: 26
# Processing file 245_1_Freeform_audio.mp4 with label 25, number 263
# Num utterances: 31
# Processing file 335_2_Northwind_audio.mp4 with label 0, number 264
# Num utterances: 13
# Processing file 323_1_Northwind_audio.mp4 with label 12, number 265
# Num utterances: 12
# Processing file 228_1_Freeform_audio.mp4 with label 1, number 266
# Num utterances: 76
# Processing file 318_3_Freeform_audio.mp4 with label 7, number 267
# Num utterances: 18
# Processing file 227_1_Northwind_audio.mp4 with label 26, number 268
# Num utterances: 12
# Processing file 239_1_Freeform_audio.mp4 with label 22, number 269
# Num utterances: 8
# Processing file 359_1_Northwind_audio.mp4 with label 33, number 270
# Num utterances: 15
# Processing file 338_1_Northwind_audio.mp4 with label 12, number 271
# Num utterances: 14
# Processing file 212_1_Freeform_audio.mp4 with label 5, number 272
# Num utterances: 20
# Processing file 221_1_Northwind_audio.mp4 with label 0, number 273
# Num utterances: 12
# Processing file 241_3_Northwind_audio.mp4 with label 40, number 274
# Num utterances: 12
# Processing file 365_2_Freeform_audio.mp4 with label 0, number 275
# Num utterances: 23
# Processing file 233_1_Northwind_audio.mp4 with label 4, number 276
# Num utterances: 14
# Processing file 207_1_Northwind_audio.mp4 with label 12, number 277
# Num utterances: 13
# Processing file 223_2_Freeform_audio.mp4 with label 0, number 278
# Num utterances: 40
# Processing file 230_1_Northwind_audio.mp4 with label 20, number 279
# Num utterances: 15
# Processing file 317_4_Northwind_audio.mp4 with label 0, number 280
# Num utterances: 15
# Processing file 247_3_Freeform_audio.mp4 with label 9, number 281
# Num utterances: 73
# Processing file 218_1_Northwind_audio.mp4 with label 31, number 282
# Num utterances: 13
# Processing file 222_1_Northwind_audio.mp4 with label 16, number 283
# Num utterances: 11
# Processing file 322_1_Northwind_audio.mp4 with label 0, number 284
# Num utterances: 16
# Processing file 245_3_Northwind_audio.mp4 with label 21, number 285
# Num utterances: 13
# Processing file 325_2_Northwind_audio.mp4 with label 25, number 286
# Num utterances: 13
# Processing file 213_2_Freeform_audio.mp4 with label 29, number 287
# Num utterances: 12
# Processing file 210_2_Northwind_audio.mp4 with label 1, number 288
# Num utterances: 14
# Processing file 205_1_Northwind_audio.mp4 with label 6, number 289
# Num utterances: 12
# Processing file 208_1_Northwind_audio.mp4 with label 5, number 290
# Num utterances: 14
# Processing file 234_2_Freeform_audio.mp4 with label 28, number 291
# Num utterances: 3
# Processing file 320_2_Freeform_audio.mp4 with label 8, number 292
# Num utterances: 8
# Processing file 203_1_Northwind_audio.mp4 with label 3, number 293
# Num utterances: 11
# Processing file 317_3_Northwind_audio.mp4 with label 17, number 294
# Num utterances: 17
# Processing file 332_4_Freeform_audio.mp4 with label 0, number 295
# Num utterances: 22
# Processing file 321_1_Northwind_audio.mp4 with label 5, number 296
# Num utterances: 15
# Processing file 220_2_Northwind_audio.mp4 with label 18, number 297
# Num utterances: 12
# Processing file 310_4_Freeform_audio.mp4 with label 19, number 298
# Num utterances: 20
# Processing file 321_1_Freeform_audio.mp4 with label 5, number 299
# Num utterances: 27
# Processing file 216_1_Freeform_audio.mp4 with label 18, number 300
# Num utterances: 10
# Procesado de archivos finalizados
# Standarization......
# Saving data
# Finished

# %% [markdown]
# Execute the next cell to load the data:

# %%
por_test=0.1
por_validation = 0.1
por_train = 0.8
num_labels = 46

def ohenc(num_labels,a):
    aux = np.zeros((a.shape[0],num_labels))
    aux[np.arange(a.shape[0]),a]=1
    return(aux)
#with open(directory_out+'datos_procesados', 'rb') as f:
#    u = pickle._Unpickler(f)
#    datos = np.array(u.load())
f = open(directory_out+'datos_procesados','r')
datos=np.array(pickle.load(f))
#datos = categories(datos)
length = len(datos)
print('Labels')
print(Counter(datos[:,1]))
print ('Number of samples: {0}'.format(length))
index = np.random.permutation(length)
index_test =index[:int(por_test*length)]
data_test = datos[index_test][:,0]
label_test = datos[index_test][:,1]
print ('Number of test samples: {0}'.format(data_test.shape))
index_validation = index[index_test.shape[0]:(index_test.shape[0]+int(por_validation*length))]
data_validation = datos[index_validation][:,0]
label_validation = datos[index_validation][:,1]
print ('Number of validation samples: {0}'.format(data_validation.shape))
index_train = index[index_test.shape[0]+index_validation.shape[0]:]
data_train = datos[index_train][:,0]
label_train = datos[index_train][:,1]
print ('Number of train samples: {0}'.format(data_train.shape))
data = []
dimensions = (data_test[0].shape[0],data_test[0].shape[1])
lentest=len(data_test)
lentrain=len(data_train)
lenvalidation=len(data_validation)
#print(data_test[0])
data_test = np.concatenate(np.concatenate(data_test))
data_train = np.concatenate(np.concatenate(data_train))
data_validation = np.concatenate(np.concatenate(data_validation))
data_test=np.expand_dims(np.transpose(data_test.reshape(dimensions[1],dimensions[0],lentest,order='F'),(2,0,1)),axis=3)
data_train=np.expand_dims(np.transpose(data_train.reshape(dimensions[1],dimensions[0],lentrain,order='F'),(2,0,1)),axis=3)
data_validation=np.expand_dims(np.transpose(data_validation.reshape(dimensions[1],dimensions[0],lenvalidation,order='F'),(2,0,1)),axis=3)
label_train= ohenc(num_labels,label_train.astype(int))
label_test= ohenc(num_labels,label_test.astype(int))
label_validation= ohenc(num_labels,label_validation.astype(int))
print('Dimension of data_test: {}'.format(data_test.shape))
print('Dimension of data_train: {}'.format(data_train.shape))
print('Dimension of data_validation: {}'.format(data_validation.shape))
print('Dimension of label_test: {}'.format(label_test.shape))
print('Dimension of label_train: {}'.format(label_train.shape))
print('Dimension of label_validation: {}'.format(label_validation.shape))
#print('Máximo label: {}'.format(max([max(label_test),max(label_train),max(label_validation)])))
# Out:
# Labels
# Counter({0: 671, 3: 319, 9: 279, 6: 259, 1: 241, 5: 206, 11: 195, 12: 189, 16: 169, 17: 155, 14: 150, 4: 148, 7: 144, 25: 141, 29: 136, 21: 134, 19: 133, 33: 123, 15: 121, 22: 120, 24: 120, 27: 113, 10: 110, 23: 93, 43: 93, 30: 83, 34: 77, 32: 76, 8: 74, 18: 72, 2: 68, 41: 54, 37: 47, 13: 46, 35: 43, 31: 34, 39: 32, 26: 27, 20: 17, 28: 17, 45: 16, 44: 15, 40: 14})
# Number of samples: 5374
# Number of test samples: (537,)
# Number of validation samples: (537,)
# Number of train samples: (4300,)
# Dimension of data_test: (537, 40, 299, 1)
# Dimension of data_train: (4300, 40, 299, 1)
# Dimension of data_validation: (537, 40, 299, 1)
# Dimension of label_test: (537, 46)
# Dimension of label_train: (4300, 46)
# Dimension of label_validation: (537, 46)

# %%
# Out:
# {'ldepression': 800, 'ndepression': 2949, 'mdepression': 782, 'hdepression': 843}

# %% [markdown]
# ## Dnn configuration

# %%
batch_size=21
dropout=0.7
#CNN CONFIGURATION
input_size= data_train[0,:,:].shape
num_cnn_nodes = 1024
num_cnn_1x1 = 400
fl_kernel_shape = (40,5)
f2_kernel_shape = (40,3)
num_labels = 46
num_layers = 2
num_pooling = 2
#MULTILAYER PERCEPTRON
num_layersp = 2
dimension_l1 = (59200,5024)
dimension_l2 = (5024,512)
learning_rate=1e-4
#TENSORBOARD
logs_path = "/home/projects/fgnovo/workspace/Tesis/cnn-log"
print(input_size)

def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 2) == np.argmax(labels, 1)) / predictions.shape[1])
def MAE(predictions,labels):
    return(np.sum(np.absolute(np.argmax(predictions,2)[0]-np.argmax(labels,1)))/predictions.shape[1])
def RMSE(predictions,labels):
    return(mean_squared_error(np.argmax(labels,1),np.argmax(predictions,2)[0])**0.5)
def pearson(predictions,labels):
    return(pearsonr(np.argmax(predictions,2)[0],np.argmax(labels,1)))
def _activation_summary(x):
    tf.histogram_summary(x.op.name + '/activations', x)
    tf.scalar_summary(x.op.name + '/sparsity', tf.nn.zero_fraction(x))
# Out:
# (40, 299, 1)

# %% [markdown]
# # DNN MODEL

# %% [markdown]
# ## DNN GRAPH

# %%
#*****************************************
#           DNN GRAPH
#*****************************************
graph = tf.Graph()
with graph.as_default():
    #********* Input data***************************
    #***********************************************
    tf_train_dataset = tf.placeholder(tf.float32, shape=(None, input_size[0], input_size[1], 1))
    tf_train_labels = tf.placeholder(tf.float32, shape=(None,num_labels))
    #tf_valid_dataset = tf.constant(data_validation.astype(np.float32))
    #tf_test_dataset = tf.constant(data_test.astype(np.float32))

    def build_cnn_graph(data,dropout):
        #CNN
        with tf.variable_scope("conv1"):
            layer1_weights = tf.get_variable("weights",[fl_kernel_shape[0],fl_kernel_shape[1],1, num_cnn_nodes],
                                                 initializer=tf.random_normal_initializer(0,0.1))
            layer1_biases = tf.get_variable("biases",[num_cnn_nodes],
                                            initializer = tf.constant_initializer(0.0))
        #CNN1x1
        with tf.variable_scope("conv1x1"):
            layer1_conv1x1 = tf.get_variable("weights",[1,1 ,num_cnn_nodes,num_cnn_1x1],
                                             initializer=tf.random_normal_initializer(0,0.01))   
        #MLP
        with tf.variable_scope("mlp1"):
            w1mlp = tf.get_variable("weights",[dimension_l1[0],dimension_l1[1]],
                                        initializer=tf.random_normal_initializer(0,0.006))
            b1mlp = tf.get_variable("biases",[dimension_l1[1]],
                                       initializer = tf.constant_initializer(0.0))  
        with tf.variable_scope("mlp2"):
            w2mlp = tf.get_variable("weights",[dimension_l2[0],dimension_l2[1]],
                                        initializer=tf.random_normal_initializer(0,0.014))
            b2mlp = tf.get_variable("biases",[dimension_l2[1]],
                                       initializer = tf.constant_initializer(0.0)) 
        #SOFTMAX
        with tf.variable_scope("softmax"):
            weight_sm = tf.get_variable("weights",[dimension_l2[1], num_labels], 
                                            initializer=tf.random_normal_initializer(0,0.044))
            bias_sm = tf.get_variable("biases",[num_labels],
                                       initializer = tf.constant_initializer(0.0)) 

        #********* Model *******************************
        #***********************************************
        #CNN
        conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='VALID')
        hidden = tf.nn.relu(conv + layer1_biases,name="conv")
        _activation_summary(hidden)
        hidden_pool = tf.nn.max_pool(hidden, ksize=[1, 1, 2, 1], strides=[1, 1, 2, 1], padding='SAME')
        hidden_d = tf.nn.dropout(hidden_pool,dropout)
        #CNN 1x1 Dimension Reduction from 1024 to 512
        conv1x1= tf.nn.conv2d(hidden_d,layer1_conv1x1,[1,1,1,1],padding='SAME')
        # conv1x1 = hidden_d
        shape = conv1x1.get_shape().as_list()
        reshape = tf.reshape(conv1x1,[-1, shape[1] *shape[2]*shape[3]])
        #MLP
        omlp1 = tf.nn.relu(tf.matmul(reshape,w1mlp)+b1mlp,name="mlp1")
        _activation_summary(omlp1)
        domlp1 = tf.nn.dropout(omlp1,dropout)
        omlp2 = tf.nn.relu(tf.matmul(domlp1,w2mlp)+b2mlp,name="mlp2")
        _activation_summary(omlp2)
        domlp2 = tf.nn.dropout(omlp2,dropout)       
        #SOFTMAX
        return(tf.matmul(domlp2, weight_sm) + bias_sm)


    for var in tf.trainable_variables():
        tf.histogram_summary(var.op.name, var)
    logits = build_cnn_graph(tf_train_dataset,dropout)
    #ERROR
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    #TRAINING
    optimizer = tf.train.AdamOptimizer(1e-4).minimize(loss)
    #PREDICTIONS
    #train_prediction = tf.nn.softmax(logits)
    tf.get_variable_scope().reuse_variables()
    valid_prediction = tf.nn.softmax(build_cnn_graph(tf_train_dataset,1.0))
    test_prediction = tf.nn.softmax(build_cnn_graph(tf_train_dataset,1.0))
    #TENSORBOARD
    merged = tf.merge_all_summaries()

# %%
def train_network(num_steps=2301): 
    print('vamos')
    #config = tf.ConfigProto()
    #config.gpu_options.allow_growth = True
    #config.log_device_placement=True
    print('sigue')
    
    with tf.Session(graph=graph) as session:
        print('Inicializando variables')
        tf.initialize_all_variables().run()
        print('Inicializando summaries')
        summary_writer = tf.train.SummaryWriter(logs_path, graph=tf.get_default_graph())
        print('Initialized')
        for step in range(num_steps):
            offset = (step * batch_size) % (label_train.shape[0] - batch_size)
            batch_data = data_train[offset:(offset + batch_size), :, :, :]
            batch_labels = label_train[offset:(offset + batch_size), :]
            feed_dict = {tf_train_dataset : batch_data, tf_train_labels: batch_labels}
            _, l,summary = session.run([optimizer, loss,merged], feed_dict=feed_dict)
            summary_writer.add_summary(summary, step )
            if (step % 50 == 0):
                print('Minibatch loss at step %d: %f' % (step, l))
                #print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
                feed_dict={tf_train_dataset:data_validation.astype(np.float32)}
                #tf.get_variable_scope().reuse_variables()
                v_prediction = session.run([valid_prediction],feed_dict=feed_dict)
                print('Validation accuracy: %.1f%%' % accuracy(np.array(v_prediction), label_validation))
                #print(np.argmax(np.array(v_prediction),axis=2))
                #print(np.array(np.array(v_prediction).shape))
                #print('********')
                #print(np.argmax(label_validation,axis=1))
                #print(label_validation.shape)
                #print(w1mlp.eval())
        feed_dict={tf_train_dataset:data_test.astype(np.float32)}
        t_prediction=session.run([test_prediction],feed_dict=feed_dict)
        print('Test accuracy: %.1f%%' % accuracy(np.array(t_prediction), label_test))
        print('Test MAE: %.2f' % MAE(np.array(t_prediction),label_test))
        print(np.argmax(np.array(t_prediction),2)[0].shape)
        print(np.argmax(label_test,1).shape)
        print('Test RSE: %.2f' % RMSE(np.array(t_prediction),label_test))
        p = pearson(np.array(t_prediction),label_test)
        print('Test Pearson Correlation:')
        print(p)
        a = np.argmax(label_test,1)
        b= np.argmax(np.array(t_prediction),2)
        print(a)
        print(b)
        f1=f1_score(np.argmax(label_test,1),np.argmax(np.array(t_prediction),2)[0],average='weighted')
        print("F1: {}".format(f1))

# %%
print('Empezando')
train_network()
# Out:
# Empezando
# vamos
# sigue
# Inicializando variables
# Inicializando summaries
# Initialized
# Minibatch loss at step 0: 3.850353
# Validation accuracy: 4.5%
# Minibatch loss at step 50: 3.400596
# Validation accuracy: 12.8%
# Minibatch loss at step 100: 3.355978
# Validation accuracy: 15.3%
# Minibatch loss at step 150: 3.228923
# Validation accuracy: 19.7%
# Minibatch loss at step 200: 3.340618
# Validation accuracy: 23.1%
# Minibatch loss at step 250: 2.276955
# Validation accuracy: 19.9%
# Minibatch loss at step 300: 1.604687
# Validation accuracy: 28.1%
# Minibatch loss at step 350: 2.041882
# Validation accuracy: 28.9%
# Minibatch loss at step 400: 1.864711
# Validation accuracy: 30.7%
# Minibatch loss at step 450: 1.895155
# Validation accuracy: 29.2%
# Minibatch loss at step 500: 0.930715
# Validation accuracy: 30.4%
# Minibatch loss at step 550: 1.028863
# Validation accuracy: 26.8%
# Minibatch loss at step 600: 0.943340
# Validation accuracy: 33.1%
# Minibatch loss at step 650: 0.710616
# Validation accuracy: 32.0%
# Minibatch loss at step 700: 0.473211
# Validation accuracy: 33.1%
# Minibatch loss at step 750: 0.651835
# Validation accuracy: 31.7%
# Minibatch loss at step 800: 0.586599
# Validation accuracy: 33.0%
# Minibatch loss at step 850: 0.500145
# Validation accuracy: 33.5%
# Minibatch loss at step 900: 0.930384
# Validation accuracy: 33.0%
# Minibatch loss at step 950: 0.374213
# Validation accuracy: 34.5%
# Minibatch loss at step 1000: 1.245499
# Validation accuracy: 34.8%
# Minibatch loss at step 1050: 1.207249
# Validation accuracy: 34.3%
# Minibatch loss at step 1100: 0.622266
# Validation accuracy: 32.8%
# Minibatch loss at step 1150: 0.220245
# Validation accuracy: 31.3%
# Minibatch loss at step 1200: 0.463148
# Validation accuracy: 34.5%
# Minibatch loss at step 1250: 0.232597
# Validation accuracy: 35.6%
# Minibatch loss at step 1300: 0.371417
# Validation accuracy: 33.3%
# Minibatch loss at step 1350: 0.322403
# Validation accuracy: 32.2%
# Minibatch loss at step 1400: 0.462600
# Validation accuracy: 35.9%
# Minibatch loss at step 1450: 0.442555
# Validation accuracy: 32.0%
# Minibatch loss at step 1500: 0.402624
# Validation accuracy: 33.7%
# Minibatch loss at step 1550: 0.177094
# Validation accuracy: 34.8%
# Minibatch loss at step 1600: 0.246552
# Validation accuracy: 37.6%
# Minibatch loss at step 1650: 0.110709
# Validation accuracy: 36.1%
# Minibatch loss at step 1700: 0.188175
# Validation accuracy: 36.9%
# Minibatch loss at step 1750: 0.047492
# Validation accuracy: 36.1%
# Minibatch loss at step 1800: 0.183195
# Validation accuracy: 35.9%
# Minibatch loss at step 1850: 0.235321
# Validation accuracy: 34.8%
# Minibatch loss at step 1900: 0.194092
# Validation accuracy: 33.3%
# Minibatch loss at step 1950: 0.164762
# Validation accuracy: 35.4%
# Minibatch loss at step 2000: 0.254211
# Validation accuracy: 33.1%
# Minibatch loss at step 2050: 0.306196
# Validation accuracy: 34.1%
# Minibatch loss at step 2100: 0.053986
# Validation accuracy: 34.5%
# Minibatch loss at step 2150: 0.035104
# Validation accuracy: 32.0%
# Minibatch loss at step 2200: 0.155671
# Validation accuracy: 33.1%
# Minibatch loss at step 2250: 0.415788
# Validation accuracy: 33.0%
# Minibatch loss at step 2300: 0.170882
# Validation accuracy: 34.8%
# Test accuracy: 35.8%
# Test MAE: 7.41
# (537,)
# (537,)
# Test RSE: 11.86
# Test Pearson Correlation:
# (0.5249729793023189, 2.2913770465150203e-39)
# [18  6  4 44 19  3 10 15 39 12 17 43 27 25 30 19 34 35  4  7 17 29 25  5 11
#   1  0 27 40 29 22  3  0 33  7  3 11 29 17 14 41  1 11 10 16 33  9  1  3  0
#  29 20  1 33 17  6 19 23 11 41  3 39 26 41  6  9  2 11 19  5  0 15 41 21  6
#   8 14  8 17  0 17  0  6 30  0 23 17 32 29  6 32 15 17  7 14 29 11 22 29 11
#   5  6  8 16 23 13 33  9  6  0 33 11  1  3 14  4  0 23 12 34  2  0  2  0  0
#   1 25  0  3 18  0  3  0 29 19 33 11  3  3 24  3 35  0 37  3  0  5  9  5 11
#   6  1  0  0  9 14  4  3 14 17  1 30 32 22  0  6 14  0  3  1 12 29 37  5 14
#  19 15  3 11 40  1  0 19 29 19 15 33 23  6 25 17 23 34 24  5  0  0 25  9 17
#   7 43  0  5  0  6  0  4  0 17  9 19 41 39 15  0 14  1  4  1 22 12  5  9 18
#   9  5 29 19  3 27  6  0  3  9  5 17 16 21  5  1 33  3  3  9 12  9  8 11  1
#   1 25  1 35 27  3  9 22  8  6 14 33 21 16 24 35  7 22  3  1 27 30  9  3 29
#  10 27  2 15 34 21 15 17 13  0  4  5  4 24 12 21 15  0 29  4 45  7 14  7  3
#  21 45 19 21 11 19  7  3  9  0 15 30 11 22 25  3 37 14 11  3  0 30 21 18 15
#   0 21 11  9 11 11  0  0 29  5  8 21 33 12  9  6 22  2  6 12  0 23  3 43  0
#  23 44 29 11  3 21 15 35 34  8 29 31  4 10 39 20 30 15  8 15 37  0  9  0  9
#  11 11  8  0 24  6 11  0 12 11 12 14  9 20 28 15  0 45 21 17 11  3 21 43 16
#  34  0 32  1 33  5 41  7  0 22 11 11 12  2 32  9  0 16  0  5  5  7 12 15  0
#  17 10  0  3 32 12  6 17 12 23  3  4 14 21  5  0 10  0  9  4 27 12 33 21  1
#  16  4  5 30 12 20  7 19  0  0 33  6  0  8  7 30 17 16 35 15  0  5  0 15  9
#  21 23  3  1 16 34  6  9 15 16 22 43 35 19  3  0  2 33 33 12 24  7 33 25  1
#  15  5  7 22 29 35  0  4  2 11  3  0 29 32  3  6 23 37 16 22 34 35  3  0 22
#  16 19 11 27 14 29 13 14 16  0 43  3]
# [[18  3  3 18 25  3 10 15 39  0 33 16 25 25 32 19  7 18  3  7 25 25 16  5
#   10  5  0 27 45 29 29 31  4 13  7  3 14 29 11 14 29 25 11 17 18 17  9  5
#    1  7 41 29  1 19 23  6  3 23 12  9  5  9 26 41  5  3 27 11  3  5  0 25
#   41 21  6 29 14  9 25  0 17  0  0 14  0 25  5 18 29  6 41 12 17  3  0  3
#   11 43  5 16  3  6 19 16 23  9 33  9 19 17 33 14 17  3 11 25 39  3  0 19
#    2  0  5 33  0 17 25  0 26  5 33  3  0 29 33 17 16  0  5 11 25 12  3 41
#    2  5  5 16  5 34  6 14  9  0 29 14 12  3  0 17  0 37 32 24  0  6 14 24
#    3 17 12 29 25  5 14 17 15  3 16  3 41 15 19  9 23 25  0 25  6 29 44 17
#   34 24  5  0 17  6  6 17 24 25  0  5  6  6 14 45  0 17  9  0  5 39 10  3
#    9 16  4  5  0 10  5  5  9  9  5 29  1  3 25  6  5  7  9  0 45 16 44  5
#   17 29 22  3 11 23 16 29  7  0  1 25  0  5 33  3 17  3  5  3 16 33 40  3
#   24  3  7  7  3 17  3 30  9  3 29 11 25  0  3 34 19 17 17  0  0  4 12 10
#   24 10  0 25  0 30  4 44  0 23  3  6  2 44 24  4 34  0  0  3 25 24 17 12
#   11 22 25  5 37 16 27  5  3 19  0  4 17  0 43 14 25 11  9  0  5 29  3 29
#   10 33 11 33 10  3  0  6  2  7 23  6 25  0 26 44 29  9  8 40 33 19 34  3
#   29 23  5 16 37 29  6 15 11 15 41  0  9  0 25 23 11 34  0  0  6  0  0  7
#    0 23  0  9 27 28 33  3  4 29  4 11 34 44 29 16 37 17  3 22 33 13 41  7
#    0 17  0 18 25  2 27 16  5 11  0  5  0  7 12 25 17 17 17  3 32 27  4  9
#   17 11 23  0  3 14 21  5  0  9  3 16  3 29  0 33 44 45 11  4  5 19  0 21
#    7 25  0  0 12 13  3  0 11  3  4 11 19  6 14  3  0  0 25 37 33  3 17 25
#   37 19 25 29 16 17 43  0 19  3  0  2 19 15  0  3  7  6 29  7 33  5  7  0
#   29  6 29 10  2  0  3  0 29  3  3 12 21 32 16 29 41 11  3  0 17 16 19  0
#   29 23 43 13  9 16  0 43  0]]
# F1: 0.338722760746
# /usr/local/lib/python2.7/dist-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
